# %% [markdown]
# <a href="https://colab.research.google.com/github/IrisFDTD/PINNs-for-education/blob/main/PINN_for_optics_eikonal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Utilizing Physical Informed Neural Networks (PINN) for solving eikonal-based Ordinary Differential Equations

# %% [markdown]
# + This notebook has been implemented by Andrés Martínez Esteban <787148@unizar.es> and Sergio Gutiérrez Rodrigo <sergut@unizar.es> as part of a Final Degree Thesis at the University of Zaragoza, 2024.
# + The code builds upon the 2nd-order ODE implementation using Physics-Informed Neural Networks (PINNs) done by Luis Medrano Navarro, Luis Martin Moreno and Sergio G Rodrigo ([Solving differential equations in physics with Deep Learning: a beginner’s guide](https://arxiv.org/abs/2307.11237)).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Definition of the problem

# %% [markdown]
# ## Eikonal

# %% [markdown]
# The Eikonal equation:
#
# \begin{equation}
#     \frac{d}{ds}\left(n\frac{d\mathbf{r}}{ds}\right)=\nabla n
# \end{equation}
#
# with vector notation $\mathbf{r}=(x,y,z)$. The left-hand side of this equation represents the curvature of the ray, while on the other side, we find the gradient of the refractive index. As a result, the ray will always bend towards regions of maximum gradient. If we consider an isotropic medium, the right-hand side would be zero since $n$ would not depend on spatial directions. This is why the trajectories are straight lines.

# %% [markdown]
# ## Black-hole model based on light ray equation

# %% [markdown]
# For a GRIN medium, particularly an optical fiber, it is consider a quadratic refractive index
#
# \begin{equation}
#     n^2(x,y)=n_o^2\left(1-g^2(x^2+y^2)\right)
# \end{equation}
#
# where $g$ is a real constant characteristic of the medium, and $n_o$ is the refractive index along the axis of symmetry $z$. It can be observed how $n(x,y)$ decreases as we move radially away from this axis. We will mainly solve two cases: one that leads to an ordinary differential equation and the latter to two coupled differential equations.

# %% [markdown]
# We can approximate using the Taylor series expansion. We obtain:
#
# $$n(x, y) =\frac{1}{1-\frac{2GM}{c^2r}}$$
#
#
# Now, we are not going to make this approximation, so we need to obtain the gradient from the first expression (which can be analytically derived by performing the calculations). Finally, considering the second approximation and the equation:
#
# $$\frac{d}{ds}\left(n\frac{dr}{ds}\right) = \nabla n$$
#
# where $r = (x(s), y(s))$. The equations to solve are as follows:
#
# $$\frac{dx}{ds}=\frac{v_x}{n}$$
#
# $$\frac{dy}{ds}=\frac{v_y}{n}$$
#
# $$\frac{dv_x}{ds}=-n^2\frac{2GM}{c^2}\frac{x}{r^3}$$
#
# $$\frac{dv_y}{ds}=-n^2\frac{2GM}{c^2}\frac{y}{r^3}$$

# %% [markdown]
# # Important libraries

# %%
## Tensorflow Keras and rest of the packages
import keras as k
import tensorflow as tf #*Library version 2.15.0
from tensorflow.keras.callbacks import ModelCheckpoint
#import tensorflow.keras as k2
from keras.layers import Dense,Input
from keras.optimizers import Adam, RMSprop
from keras.models import load_model, save_model
from keras.saving import register_keras_serializable
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
import cmath
import math
from tensorflow import keras
import time
import pandas as pd

# %% [markdown]
# # Auxiliary functions

# %%
def plot_history_by_key(keys):
  import matplotlib.pyplot as plt
  for key in keys:
    plt.plot(history.history[key],marker='o',markersize=0.0, linewidth=1.0,label=key)
  plt.xlabel('epoch')
  plt.legend()
  plt.show()
  return history.history[key]

# %% [markdown]
# # We define the radius (r) and the refractive index (n).

# %%
def r (x,y):
  return (tf.sqrt(x**2+y**2))

def n_ind(x,y,A):
  return (1.0/(1.0-A/r(x,y)))

# %% [markdown]
# # Definition of the PINN

# %%
class ODE_2nd(tf.keras.Model):
    def set_ODE_param(self,z0,x0,dx_dz0,A, auxx, aux2):
        '''
        Set parameters and initial conditions for the ODE

        '''
        self.z0=tf.constant([z0], dtype=tf.float32)
        self.x0_true=tf.constant(x0, dtype=tf.float32)
        self.dx_dz0_true=tf.constant(dx_dz0, dtype=tf.float32)
        self.A=tf.constant(A,dtype=tf.float32)
        self.auxx=tf.constant(auxx,dtype=tf.float32)
        self.aux2=tf.constant(aux2,dtype=tf.float32)

    def train_step(self, data):
        '''
        Training ocurrs here
        '''
        z, x_true = data
        with tf.GradientTape() as tape:
            #* Initial conditions
            tape.watch(self.z0)
            tape.watch(self.x0_true)
            tape.watch(self.dx_dz0_true)
            tape.watch(self.A)
            tape.watch(z)

            with tf.GradientTape() as tape0:
                    tape0.watch(self.z0)
                    x0_pred= self(self.z0,training=False)
                    tape0.watch(x0_pred)

            with tf.GradientTape() as tape1:
                tape1.watch(z)
                x=self(z,training=False)
                tape1.watch(x)
            dx_dz=tape1.jacobian(x,z)
            dx_dz=tf.squeeze(dx_dz)
            dx_dz=tf.reshape(dx_dz,shape=x.shape)
            tape.watch(z)
            tape.watch(x)
            tape.watch(dx_dz)

 
            #* Definition of r and n
            r=tf.math.sqrt(x[:,0]**2+x[:,1]**2)
            n=1.0/(1.0-self.A/r)
            aux=[0.0,0.0,0.0,0.0]
            aux=tf.reshape(aux,shape=x.shape)
  

            #? Original ODE's order
            '''
            lossODE= self.compiled_loss(dx_dz[:,0],x[:,2]/n)\
                    +self.compiled_loss(dx_dz[:,1],x[:,3]/n)\
                    +self.compiled_loss(dx_dz[:,2],-self.A*tf.math.pow(n,2)*x[:,0]/tf.math.pow(r,3))\
                    +self.compiled_loss(dx_dz[:,3],-self.A*tf.math.pow(n,2)*x[:,1]/tf.math.pow(r,3))

            '''
            '''
            #? Alternative ODE's order (1)
            lossODE= self.compiled_loss(n*dx_dz[:,0],x[:,2])\
                    +self.compiled_loss(n*dx_dz[:,1],x[:,3])\
                    +self.compiled_loss(tf.math.pow(r,3)*dx_dz[:,2]/tf.math.pow(n,2),-self.A*x[:,0])\
                    +self.compiled_loss(tf.math.pow(r,3)*dx_dz[:,3]/tf.math.pow(n,2),-self.A*x[:,1])
                    #+self.compiled_loss(A/tf.math.pow((x[:,0]*x[:,0]+x[:,1]*x[:,1]),0.5),aux[:,0])

            '''
            
            #? Alternative ODE's order (2)
            lossODE= self.compiled_loss(dx_dz[:,0],x[:,2]/n)\
                    +self.compiled_loss(dx_dz[:,1],x[:,3]/n)\
                    +self.compiled_loss(tf.math.pow(r,3)*dx_dz[:,2],-self.A*tf.math.pow(n,2)*x[:,0])*5\
                    +self.compiled_loss(tf.math.pow(r,3)*dx_dz[:,3],-self.A*tf.math.pow(n,2)*x[:,1])*10
                


            #* initial condition loss
            lossODE= lossODE\
                  + self.compiled_loss(x0_pred,self.x0_true) \
                  
            #* pushpin loss
            aux_pred=self(self.aux2, training=False)
            loss=lossODE\
                +self.compiled_loss(self.auxx,aux_pred)


        gradients = tape.gradient(loss, self.trainable_weights)
        self.optimizer.apply_gradients(zip(gradients, self.trainable_weights))
        self.compiled_metrics.update_state(x_true, x)
        metrics={m.name: m.result() for m in self.metrics}
        metrics.pop('mean_squared_error')
        metrics['z']=z
        metrics['x0']=x0_pred[:,0]
        metrics['y0']=x0_pred[:,1]
        metrics['vx0']=x0_pred[:,2]
        metrics['vy0']=x0_pred[:,3]
        metrics['x']=x[:,0]
        metrics['y']=x[:,1]
        metrics['vx']=x[:,2]
        metrics['vy']=x[:,3]
        metrics['n'] = n
        metrics['r'] = r
        print(self.A)
        return metrics

# %% [markdown]
# + Problem's coordinates
# $$A=2GM/c^2$$
# $$n(x, y) =\frac{1}{1-\frac{A}{r}}$$
#
# $$\frac{dx}{ds}=\frac{v_x}{n}$$
#
# $$\frac{dy}{ds}=\frac{v_y}{n}$$
#
# $$\frac{dv_x}{ds}=-n^2\frac{2GM}{c^2}\frac{x}{r^3}$$
#
# $$\frac{dv_y}{ds}=-n^2\frac{2GM}{c^2}\frac{y}{r^3}$$
#
# + PINN's coordinates
# $$\vec x=(x_0,x_1,x_2,x_3)=(x,y,v_x,v_y)$$

# %% [markdown]
# # Common parameters

# %%
A=8.0/100        #it represents the factor 2GM/c^2
GM_c2= A/2   #it represents the factor GM/c^2
x0_rk = -1; x_ini= -1
y0_rk = 0.5; y_ini=0.5
vx0_rk=1   ; vx_ini=1
vy0_rk = 0.0  ; vy_ini=0.0

# %% [markdown]
# # Define the PINN

# %%
#* Initial conditions NN
n_ini=n_ind(x_ini, y_ini,A).numpy()
x0=[x_ini,y_ini,vx_ini,vy_ini]
dx_dz0=[vx_ini/n_ini,
        vy_ini/n_ini,
        -n_ini**2*A*x_ini/(r(x_ini,y_ini).numpy())**3,
        -n_ini**2*A*y_ini/(r(x_ini,y_ini).numpy())**3]
print("n(0)=",n_ini)
print('x(0)=',x0)
print('dx_dz(0)=',dx_dz0)




N_train_max =200  #number of training points
zmax = 2          #range of the predicted function
N_intervalos=1    #number of pushpins=N_intervalos-1
salto=int(N_train_max/N_intervalos)
salto_z=zmax/N_intervalos
norm=N_train_max


N_train=0
zmed=0
z0 = 0
auxx=[]
aux2=[]


#* Input and output neurons (from the data)
input_neurons  = 1
output_neurons = 4

#* Hiperparameters
batch_size = 1
epochs = 8000



#* Stops after certain epochs without improving and safe the best weight
#! If the simulation ends normally instead of by this callback, the program will take last weights not best, for avoiding this implement this callback with the checkpoint_callback
callbacks = tf.keras.callbacks.EarlyStopping(monitor='loss',
                                            patience=1000,
                                            restore_best_weights=True)

for chinch in range (N_intervalos):

    #* Saves the training data
    checkpoint_callback = ModelCheckpoint(filepath=f'black_hole_models/weights_inter={N_intervalos}_y={y_ini}_N={N_train_max}.h5', 
                                  monitor='loss', 
                                  save_best_only=True, 
                                  save_weights_only=True, 
                                  mode='min',
                                  verbose=1)

    #* Define the neural network model
    initializer = tf.keras.initializers.GlorotUniform(seed=5)
    activation='tanh'
    input=Input(shape=(input_neurons,))
    x=Dense(500, activation=activation,kernel_initializer=initializer)(input)
    x=Dense(500, activation=activation,kernel_initializer=initializer)(x)
    x=Dense(500, activation=activation,kernel_initializer=initializer)(x)
    x=Dense(500, activation=activation,kernel_initializer=initializer)(x)
    x=Dense(500, activation=activation,kernel_initializer=initializer)(x)
    output = Dense(output_neurons,kernel_initializer=initializer,activation=None)(x)

    #* Build the model
    model=ODE_2nd(input,output)

    #*Define the metrics, optimizer and loss
    loss= tf.keras.losses.MeanSquaredError()
    metrics=tf.keras.metrics.MeanSquaredError()
    optimizer= Adam(learning_rate=0.00005)


    model.compile(loss=loss,
        optimizer=optimizer,
        metrics=metrics,
        run_eagerly=False)
    model.summary() 

    N_train=N_train+salto
    zmed=zmed+salto_z

    z_train=np.linspace(z0,zmed,N_train)
    z_train=np.reshape(z_train,(N_train,1))
    y_train=np.zeros((z_train.shape[0],1))

    #* Set ODE parameters and initial conditions
    model.set_ODE_param(z0=[z0],x0=x0,dx_dz0=dx_dz0,A=A, auxx=auxx, aux2=aux2)

    if(chinch==(N_intervalos-1)):
        history=model.fit(z_train, y_train, batch_size=1, epochs=4000,verbose=1,
                    callbacks=checkpoint_callback) #,shuffle=False)
        model.load_weights(f'black_hole_models/weights_inter={N_intervalos}_y={y_ini}_N={N_train_max}.h5')
        xy_pred=model.predict(z_train)

        
    else:               
        #history=model.fit(z_train, y_train, batch_size=1, epochs=epochs,verbose=1,
                    #callbacks=[callbacks, stop_on_loss_callback]) #,shuffle=False)
        history=model.fit(z_train, y_train, batch_size=1, epochs=epochs,verbose=1,
                    callbacks=[checkpoint_callback,callbacks]) #,shuffle=False)
        model.load_weights(f'black_hole_models/weights_inter={N_intervalos}_y={y_ini}_N={N_train_max}.h5')
        xy_pred=model.predict(z_train)
            
    auxx.append(xy_pred[N_train-1])
    aux2.append(z_train[N_train-1])
# Out:
# n(0)= 1.0770688
# x(0)= [-1, 0.5, 0.9284458247200068, 0.0]
# dx_dz(0)= [0.862011618766798, 0.0, 0.06640669161909757, -0.033203345809548784]
# Model: "ode_2nd_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 1)]               0
#
#  dense_12 (Dense)            (None, 500)               1000
#
#  dense_13 (Dense)            (None, 500)               250500
#
#  dense_14 (Dense)            (None, 500)               250500
#
#  dense_15 (Dense)            (None, 500)               250500
#
#  dense_16 (Dense)            (None, 500)               250500
#
#  dense_17 (Dense)            (None, 4)                 2004
#
# =================================================================
# Total params: 1005004 (3.83 MB)
# Trainable params: 1005004 (3.83 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/4000
# tf.Tensor(0.08, shape=(), dtype=float32)
# tf.Tensor(0.08, shape=(), dtype=float32)
# 197/200 [============================>.] - ETA: 0s - loss: 241.3029 - z: 0.9957 - x0: 0.0877 - y0: -0.0028 - vx0: 0.0104 - vy0: -0.0031 - x: 1.6442 - y: -0.0404 - vx: 0.0522 - vy: 0.0170 - n: 2.8763 - r: 1.6448
# Epoch 1: loss improved from inf to 237.69420, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 2s 5ms/step - loss: 237.6942 - z: 1.0044 - x0: 0.0881 - y0: -0.0028 - vx0: 0.0105 - vy0: -0.0032 - x: 1.6673 - y: -0.0411 - vx: 0.0514 - vy: 0.0165 - n: 2.8396 - r: 1.6678
# Epoch 2/4000
# 200/200 [==============================] - ETA: 0s - loss: 0.7754 - z: 1.0000 - x0: 0.1094 - y0: -0.0037 - vx0: 0.0214 - vy0: -0.0112 - x: 2.0222 - y: -0.0556 - vx: 0.0189 - vy: -0.0116 - n: 1.1059 - r: 2.0230
# Epoch 2: loss improved from 237.69420 to 0.77541, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.7754 - z: 1.0000 - x0: 0.1094 - y0: -0.0037 - vx0: 0.0214 - vy0: -0.0112 - x: 2.0225 - y: -0.0556 - vx: 0.0190 - vy: -0.0116 - n: 1.1056 - r: 2.0232
# Epoch 3/4000
# 190/200 [===========================>..] - ETA: 0s - loss: 0.7673 - z: 1.0020 - x0: 0.1094 - y0: -0.0037 - vx0: 0.0318 - vy0: -0.0184 - x: 2.0263 - y: -0.0557 - vx: 0.0294 - vy: -0.0187 - n: 1.0998 - r: 2.0270
# Epoch 3: loss improved from 0.77541 to 0.76729, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.7673 - z: 0.9951 - x0: 0.1094 - y0: -0.0037 - vx0: 0.0320 - vy0: -0.0185 - x: 2.0128 - y: -0.0553 - vx: 0.0296 - vy: -0.0189 - n: 1.1134 - r: 2.0135
# Epoch 4/4000
# 192/200 [===========================>..] - ETA: 0s - loss: 0.7582 - z: 1.0090 - x0: 0.1094 - y0: -0.0037 - vx0: 0.0421 - vy0: -0.0248 - x: 2.0388 - y: -0.0560 - vx: 0.0396 - vy: -0.0251 - n: 1.1044 - r: 2.0396
# Epoch 4: loss improved from 0.76729 to 0.75955, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.7596 - z: 1.0025 - x0: 0.1094 - y0: -0.0037 - vx0: 0.0423 - vy0: -0.0250 - x: 2.0269 - y: -0.0557 - vx: 0.0398 - vy: -0.0252 - n: 1.1055 - r: 2.0277
# Epoch 5/4000
# 190/200 [===========================>..] - ETA: 0s - loss: 0.7502 - z: 1.0101 - x0: 0.1094 - y0: -0.0037 - vx0: 0.0522 - vy0: -0.0302 - x: 2.0401 - y: -0.0561 - vx: 0.0495 - vy: -0.0304 - n: 1.1025 - r: 2.0409
# Epoch 5: loss improved from 0.75955 to 0.75209, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.7521 - z: 0.9951 - x0: 0.1094 - y0: -0.0037 - vx0: 0.0525 - vy0: -0.0303 - x: 2.0129 - y: -0.0553 - vx: 0.0499 - vy: -0.0306 - n: 1.1111 - r: 2.0136
# Epoch 6/4000
# 200/200 [==============================] - ETA: 0s - loss: 0.7447 - z: 1.0000 - x0: 0.1094 - y0: -0.0037 - vx0: 0.0625 - vy0: -0.0347 - x: 2.0222 - y: -0.0556 - vx: 0.0597 - vy: -0.0347 - n: 1.1059 - r: 2.0230
# Epoch 6: loss improved from 0.75209 to 0.74469, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.7447 - z: 1.0019 - x0: 0.1094 - y0: -0.0037 - vx0: 0.0625 - vy0: -0.0347 - x: 2.0259 - y: -0.0557 - vx: 0.0597 - vy: -0.0347 - n: 1.1055 - r: 2.0266
# Epoch 7/4000
# 193/200 [===========================>..] - ETA: 0s - loss: 0.7386 - z: 0.9959 - x0: 0.1094 - y0: -0.0037 - vx0: 0.0723 - vy0: -0.0380 - x: 2.0161 - y: -0.0553 - vx: 0.0694 - vy: -0.0379 - n: 1.0940 - r: 2.0169
# Epoch 7: loss improved from 0.74469 to 0.73741, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.7374 - z: 1.0041 - x0: 0.1094 - y0: -0.0037 - vx0: 0.0725 - vy0: -0.0380 - x: 2.0294 - y: -0.0558 - vx: 0.0695 - vy: -0.0380 - n: 1.1055 - r: 2.0302
# Epoch 8/4000
# 200/200 [==============================] - ETA: 0s - loss: 0.7301 - z: 1.0000 - x0: 0.1094 - y0: -0.0037 - vx0: 0.0825 - vy0: -0.0404 - x: 2.0222 - y: -0.0556 - vx: 0.0795 - vy: -0.0403 - n: 1.1059 - r: 2.0229
# Epoch 8: loss improved from 0.73741 to 0.73013, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.7301 - z: 0.9980 - x0: 0.1094 - y0: -0.0037 - vx0: 0.0825 - vy0: -0.0404 - x: 2.0186 - y: -0.0554 - vx: 0.0795 - vy: -0.0403 - n: 1.1057 - r: 2.0193
# Epoch 9/4000
# 190/200 [===========================>..] - ETA: 0s - loss: 0.7222 - z: 1.0057 - x0: 0.1094 - y0: -0.0037 - vx0: 0.0922 - vy0: -0.0421 - x: 2.0326 - y: -0.0559 - vx: 0.0889 - vy: -0.0418 - n: 1.1062 - r: 2.0334
# Epoch 9: loss improved from 0.73013 to 0.72303, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.7230 - z: 1.0006 - x0: 0.1094 - y0: -0.0037 - vx0: 0.0925 - vy0: -0.0421 - x: 2.0235 - y: -0.0556 - vx: 0.0893 - vy: -0.0418 - n: 1.1055 - r: 2.0242
# Epoch 10/4000
# 198/200 [============================>.] - ETA: 0s - loss: 0.7161 - z: 0.9995 - x0: 0.1094 - y0: -0.0037 - vx0: 0.1023 - vy0: -0.0432 - x: 2.0212 - y: -0.0555 - vx: 0.0990 - vy: -0.0429 - n: 1.1064 - r: 2.0220
# Epoch 10: loss improved from 0.72303 to 0.71598, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.7160 - z: 0.9975 - x0: 0.1094 - y0: -0.0037 - vx0: 0.1024 - vy0: -0.0432 - x: 2.0177 - y: -0.0554 - vx: 0.0991 - vy: -0.0428 - n: 1.1058 - r: 2.0184
# Epoch 11/4000
# 194/200 [============================>.] - ETA: 0s - loss: 0.7072 - z: 1.0072 - x0: 0.1094 - y0: -0.0037 - vx0: 0.1120 - vy0: -0.0439 - x: 2.0346 - y: -0.0560 - vx: 0.1088 - vy: -0.0435 - n: 1.1071 - r: 2.0354
# Epoch 11: loss improved from 0.71598 to 0.70878, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.7088 - z: 0.9987 - x0: 0.1094 - y0: -0.0037 - vx0: 0.1122 - vy0: -0.0440 - x: 2.0199 - y: -0.0555 - vx: 0.1090 - vy: -0.0435 - n: 1.1056 - r: 2.0207
# Epoch 12/4000
# 198/200 [============================>.] - ETA: 0s - loss: 0.7025 - z: 0.9984 - x0: 0.1094 - y0: -0.0037 - vx0: 0.1220 - vy0: -0.0443 - x: 2.0197 - y: -0.0555 - vx: 0.1185 - vy: -0.0438 - n: 1.1063 - r: 2.0205
# Epoch 12: loss improved from 0.70878 to 0.70209, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.7021 - z: 1.0047 - x0: 0.1094 - y0: -0.0037 - vx0: 0.1221 - vy0: -0.0443 - x: 2.0304 - y: -0.0558 - vx: 0.1184 - vy: -0.0438 - n: 1.1055 - r: 2.0312
# Epoch 13/4000
# 189/200 [===========================>..] - ETA: 0s - loss: 0.6962 - z: 0.9940 - x0: 0.1094 - y0: -0.0037 - vx0: 0.1317 - vy0: -0.0445 - x: 2.0109 - y: -0.0552 - vx: 0.1282 - vy: -0.0439 - n: 1.1036 - r: 2.0117
# Epoch 13: loss improved from 0.70209 to 0.69503, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.6950 - z: 1.0002 - x0: 0.1094 - y0: -0.0037 - vx0: 0.1320 - vy0: -0.0445 - x: 2.0228 - y: -0.0556 - vx: 0.1284 - vy: -0.0439 - n: 1.1056 - r: 2.0236
# Epoch 14/4000
# 192/200 [===========================>..] - ETA: 0s - loss: 0.6857 - z: 1.0152 - x0: 0.1094 - y0: -0.0037 - vx0: 0.1416 - vy0: -0.0447 - x: 2.0506 - y: -0.0564 - vx: 0.1374 - vy: -0.0440 - n: 1.1014 - r: 2.0514
# Epoch 14: loss improved from 0.69503 to 0.68822, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.6882 - z: 0.9952 - x0: 0.1094 - y0: -0.0037 - vx0: 0.1419 - vy0: -0.0447 - x: 2.0131 - y: -0.0553 - vx: 0.1378 - vy: -0.0440 - n: 1.1090 - r: 2.0138
# Epoch 15/4000
# 188/200 [===========================>..] - ETA: 0s - loss: 0.6778 - z: 1.0219 - x0: 0.1094 - y0: -0.0037 - vx0: 0.1514 - vy0: -0.0447 - x: 2.0629 - y: -0.0567 - vx: 0.1472 - vy: -0.0441 - n: 1.1056 - r: 2.0637
# Epoch 15: loss improved from 0.68822 to 0.68136, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.6814 - z: 0.9973 - x0: 0.1094 - y0: -0.0037 - vx0: 0.1517 - vy0: -0.0447 - x: 2.0172 - y: -0.0554 - vx: 0.1477 - vy: -0.0442 - n: 1.1058 - r: 2.0179
# Epoch 16/4000
# 194/200 [============================>.] - ETA: 0s - loss: 0.6754 - z: 0.9943 - x0: 0.1094 - y0: -0.0037 - vx0: 0.1614 - vy0: -0.0448 - x: 2.0109 - y: -0.0553 - vx: 0.1570 - vy: -0.0439 - n: 1.1080 - r: 2.0116
# Epoch 16: loss improved from 0.68136 to 0.67452, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.6745 - z: 0.9986 - x0: 0.1094 - y0: -0.0037 - vx0: 0.1615 - vy0: -0.0448 - x: 2.0197 - y: -0.0555 - vx: 0.1572 - vy: -0.0440 - n: 1.1056 - r: 2.0205
# Epoch 17/4000
# 192/200 [===========================>..] - ETA: 0s - loss: 0.6696 - z: 0.9912 - x0: 0.1094 - y0: -0.0037 - vx0: 0.1712 - vy0: -0.0449 - x: 2.0057 - y: -0.0551 - vx: 0.1665 - vy: -0.0440 - n: 1.1085 - r: 2.0065
# Epoch 17: loss improved from 0.67452 to 0.66795, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.6679 - z: 1.0014 - x0: 0.1094 - y0: -0.0037 - vx0: 0.1714 - vy0: -0.0449 - x: 2.0249 - y: -0.0556 - vx: 0.1667 - vy: -0.0442 - n: 1.1055 - r: 2.0257
# Epoch 18/4000
# 190/200 [===========================>..] - ETA: 0s - loss: 0.6621 - z: 0.9956 - x0: 0.1094 - y0: -0.0037 - vx0: 0.1810 - vy0: -0.0448 - x: 2.0130 - y: -0.0553 - vx: 0.1762 - vy: -0.0441 - n: 1.1091 - r: 2.0137
# Epoch 18: loss improved from 0.66795 to 0.66134, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.6613 - z: 1.0024 - x0: 0.1094 - y0: -0.0037 - vx0: 0.1812 - vy0: -0.0448 - x: 2.0267 - y: -0.0557 - vx: 0.1765 - vy: -0.0441 - n: 1.1055 - r: 2.0275
# Epoch 19/4000
# 189/200 [===========================>..] - ETA: 0s - loss: 0.6551 - z: 0.9998 - x0: 0.1094 - y0: -0.0037 - vx0: 0.1908 - vy0: -0.0449 - x: 2.0216 - y: -0.0556 - vx: 0.1853 - vy: -0.0439 - n: 1.1081 - r: 2.0224
# Epoch 19: loss improved from 0.66134 to 0.65480, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.6548 - z: 1.0039 - x0: 0.1094 - y0: -0.0037 - vx0: 0.1911 - vy0: -0.0449 - x: 2.0292 - y: -0.0558 - vx: 0.1858 - vy: -0.0439 - n: 1.1055 - r: 2.0299
# Epoch 20/4000
# 198/200 [============================>.] - ETA: 0s - loss: 0.6485 - z: 0.9983 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2009 - vy0: -0.0451 - x: 2.0193 - y: -0.0555 - vx: 0.1953 - vy: -0.0441 - n: 1.1064 - r: 2.0200
# Epoch 20: loss improved from 0.65480 to 0.64812, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.6481 - z: 0.9974 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2009 - vy0: -0.0451 - x: 2.0174 - y: -0.0554 - vx: 0.1953 - vy: -0.0441 - n: 1.1058 - r: 2.0182
# Epoch 21/4000
# 197/200 [============================>.] - ETA: 0s - loss: 0.6422 - z: 0.9982 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2107 - vy0: -0.0450 - x: 2.0188 - y: -0.0555 - vx: 0.2051 - vy: -0.0441 - n: 1.1067 - r: 2.0195
# Epoch 21: loss improved from 0.64812 to 0.64181, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.6418 - z: 1.0022 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2108 - vy0: -0.0450 - x: 2.0264 - y: -0.0557 - vx: 0.2053 - vy: -0.0441 - n: 1.1055 - r: 2.0271
# Epoch 22/4000
# 198/200 [============================>.] - ETA: 0s - loss: 0.6345 - z: 1.0028 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2205 - vy0: -0.0451 - x: 2.0271 - y: -0.0557 - vx: 0.2145 - vy: -0.0441 - n: 1.1062 - r: 2.0279
# Epoch 22: loss improved from 0.64181 to 0.63503, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.6350 - z: 1.0004 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2206 - vy0: -0.0451 - x: 2.0232 - y: -0.0556 - vx: 0.2146 - vy: -0.0441 - n: 1.1056 - r: 2.0239
# Epoch 23/4000
# 196/200 [============================>.] - ETA: 0s - loss: 0.6277 - z: 1.0045 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2303 - vy0: -0.0451 - x: 2.0302 - y: -0.0558 - vx: 0.2243 - vy: -0.0440 - n: 1.1064 - r: 2.0309
# Epoch 23: loss improved from 0.63503 to 0.62838, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.6284 - z: 1.0021 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2305 - vy0: -0.0451 - x: 2.0262 - y: -0.0557 - vx: 0.2245 - vy: -0.0440 - n: 1.1055 - r: 2.0269
# Epoch 24/4000
# 200/200 [==============================] - ETA: 0s - loss: 0.6220 - z: 1.0000 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2403 - vy0: -0.0451 - x: 2.0221 - y: -0.0556 - vx: 0.2340 - vy: -0.0441 - n: 1.1059 - r: 2.0229
# Epoch 24: loss improved from 0.62838 to 0.62203, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.6220 - z: 0.9958 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2403 - vy0: -0.0451 - x: 2.0142 - y: -0.0554 - vx: 0.2340 - vy: -0.0441 - n: 1.1065 - r: 2.0150
# Epoch 25/4000
# 199/200 [============================>.] - ETA: 0s - loss: 0.6157 - z: 1.0007 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2501 - vy0: -0.0450 - x: 2.0232 - y: -0.0556 - vx: 0.2436 - vy: -0.0441 - n: 1.1062 - r: 2.0239
# Epoch 25: loss improved from 0.62203 to 0.61584, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.6158 - z: 0.9993 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2502 - vy0: -0.0450 - x: 2.0211 - y: -0.0555 - vx: 0.2436 - vy: -0.0441 - n: 1.1056 - r: 2.0219
# Epoch 26/4000
# 192/200 [===========================>..] - ETA: 0s - loss: 0.6087 - z: 1.0046 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2598 - vy0: -0.0451 - x: 2.0307 - y: -0.0558 - vx: 0.2530 - vy: -0.0441 - n: 1.1076 - r: 2.0315
# Epoch 26: loss improved from 0.61584 to 0.60933, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.6093 - z: 1.0031 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2600 - vy0: -0.0451 - x: 2.0278 - y: -0.0557 - vx: 0.2533 - vy: -0.0441 - n: 1.1055 - r: 2.0286
# Epoch 27/4000
# 195/200 [============================>.] - ETA: 0s - loss: 0.6023 - z: 1.0048 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2697 - vy0: -0.0451 - x: 2.0308 - y: -0.0558 - vx: 0.2626 - vy: -0.0440 - n: 1.1052 - r: 2.0316
# Epoch 27: loss improved from 0.60933 to 0.60312, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.6031 - z: 0.9975 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2699 - vy0: -0.0451 - x: 2.0175 - y: -0.0554 - vx: 0.2628 - vy: -0.0440 - n: 1.1058 - r: 2.0183
# Epoch 28/4000
# 196/200 [============================>.] - ETA: 0s - loss: 0.5976 - z: 0.9961 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2796 - vy0: -0.0451 - x: 2.0147 - y: -0.0554 - vx: 0.2724 - vy: -0.0441 - n: 1.1072 - r: 2.0154
# Epoch 28: loss improved from 0.60312 to 0.59684, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5968 - z: 1.0018 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2797 - vy0: -0.0451 - x: 2.0255 - y: -0.0557 - vx: 0.2724 - vy: -0.0441 - n: 1.1055 - r: 2.0263
# Epoch 29/4000
# 195/200 [============================>.] - ETA: 0s - loss: 0.5905 - z: 1.0004 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2894 - vy0: -0.0452 - x: 2.0222 - y: -0.0556 - vx: 0.2818 - vy: -0.0441 - n: 1.1072 - r: 2.0229
# Epoch 29: loss improved from 0.59684 to 0.59056, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5906 - z: 1.0004 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2896 - vy0: -0.0452 - x: 2.0230 - y: -0.0556 - vx: 0.2819 - vy: -0.0441 - n: 1.1056 - r: 2.0238
# Epoch 30/4000
# 198/200 [============================>.] - ETA: 0s - loss: 0.5839 - z: 1.0024 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2994 - vy0: -0.0450 - x: 2.0261 - y: -0.0557 - vx: 0.2916 - vy: -0.0440 - n: 1.1064 - r: 2.0269
# Epoch 30: loss improved from 0.59056 to 0.58437, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5844 - z: 0.9985 - x0: 0.1094 - y0: -0.0037 - vx0: 0.2994 - vy0: -0.0450 - x: 2.0194 - y: -0.0555 - vx: 0.2917 - vy: -0.0440 - n: 1.1057 - r: 2.0202
# Epoch 31/4000
# 192/200 [===========================>..] - ETA: 0s - loss: 0.5790 - z: 0.9961 - x0: 0.1094 - y0: -0.0037 - vx0: 0.3091 - vy0: -0.0450 - x: 2.0145 - y: -0.0554 - vx: 0.3011 - vy: -0.0441 - n: 1.1083 - r: 2.0153
# Epoch 31: loss improved from 0.58437 to 0.57816, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5782 - z: 1.0034 - x0: 0.1094 - y0: -0.0037 - vx0: 0.3093 - vy0: -0.0450 - x: 2.0282 - y: -0.0558 - vx: 0.3013 - vy: -0.0440 - n: 1.1055 - r: 2.0289
# Epoch 32/4000
# 198/200 [============================>.] - ETA: 0s - loss: 0.5735 - z: 0.9968 - x0: 0.1094 - y0: -0.0037 - vx0: 0.3191 - vy0: -0.0453 - x: 2.0160 - y: -0.0554 - vx: 0.3111 - vy: -0.0441 - n: 1.1066 - r: 2.0168
# Epoch 32: loss improved from 0.57816 to 0.57286, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5729 - z: 0.9995 - x0: 0.1094 - y0: -0.0037 - vx0: 0.3192 - vy0: -0.0453 - x: 2.0214 - y: -0.0556 - vx: 0.3112 - vy: -0.0440 - n: 1.1056 - r: 2.0221
# Epoch 33/4000
# 198/200 [============================>.] - ETA: 0s - loss: 0.5656 - z: 1.0015 - x0: 0.1094 - y0: -0.0037 - vx0: 0.3290 - vy0: -0.0451 - x: 2.0243 - y: -0.0557 - vx: 0.3208 - vy: -0.0441 - n: 1.1065 - r: 2.0251
# Epoch 33: loss improved from 0.57286 to 0.56593, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5659 - z: 1.0001 - x0: 0.1094 - y0: -0.0037 - vx0: 0.3290 - vy0: -0.0451 - x: 2.0224 - y: -0.0556 - vx: 0.3209 - vy: -0.0441 - n: 1.1056 - r: 2.0232
# Epoch 34/4000
# 194/200 [============================>.] - ETA: 0s - loss: 0.5581 - z: 1.0117 - x0: 0.1094 - y0: -0.0037 - vx0: 0.3387 - vy0: -0.0451 - x: 2.0433 - y: -0.0562 - vx: 0.3300 - vy: -0.0441 - n: 1.1057 - r: 2.0441
# Epoch 34: loss improved from 0.56593 to 0.56007, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5601 - z: 0.9955 - x0: 0.1094 - y0: -0.0037 - vx0: 0.3388 - vy0: -0.0451 - x: 2.0134 - y: -0.0554 - vx: 0.3303 - vy: -0.0441 - n: 1.1071 - r: 2.0142
# Epoch 35/4000
# 189/200 [===========================>..] - ETA: 0s - loss: 0.5529 - z: 1.0032 - x0: 0.1094 - y0: -0.0037 - vx0: 0.3485 - vy0: -0.0451 - x: 2.0288 - y: -0.0558 - vx: 0.3399 - vy: -0.0441 - n: 1.0906 - r: 2.0296
# Epoch 35: loss improved from 0.56007 to 0.55380, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5538 - z: 1.0007 - x0: 0.1094 - y0: -0.0037 - vx0: 0.3488 - vy0: -0.0451 - x: 2.0235 - y: -0.0557 - vx: 0.3402 - vy: -0.0441 - n: 1.1056 - r: 2.0242
# Epoch 36/4000
# 199/200 [============================>.] - ETA: 0s - loss: 0.5482 - z: 0.9981 - x0: 0.1094 - y0: -0.0037 - vx0: 0.3586 - vy0: -0.0451 - x: 2.0182 - y: -0.0555 - vx: 0.3500 - vy: -0.0441 - n: 1.1063 - r: 2.0190
# Epoch 36: loss improved from 0.55380 to 0.54783, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5478 - z: 1.0019 - x0: 0.1094 - y0: -0.0037 - vx0: 0.3587 - vy0: -0.0451 - x: 2.0255 - y: -0.0557 - vx: 0.3500 - vy: -0.0441 - n: 1.1055 - r: 2.0262
# Epoch 37/4000
# 192/200 [===========================>..] - ETA: 0s - loss: 0.5416 - z: 1.0032 - x0: 0.1094 - y0: -0.0037 - vx0: 0.3683 - vy0: -0.0451 - x: 2.0269 - y: -0.0558 - vx: 0.3595 - vy: -0.0441 - n: 1.1075 - r: 2.0276
# Epoch 37: loss improved from 0.54783 to 0.54203, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5420 - z: 1.0018 - x0: 0.1094 - y0: -0.0037 - vx0: 0.3685 - vy0: -0.0451 - x: 2.0253 - y: -0.0557 - vx: 0.3597 - vy: -0.0441 - n: 1.1055 - r: 2.0261
# Epoch 38/4000
# 193/200 [===========================>..] - ETA: 0s - loss: 0.5399 - z: 0.9808 - x0: 0.1094 - y0: -0.0037 - vx0: 0.3782 - vy0: -0.0450 - x: 1.9872 - y: -0.0546 - vx: 0.3693 - vy: -0.0441 - n: 1.1086 - r: 1.9880
# Epoch 38: loss improved from 0.54203 to 0.53634, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5363 - z: 1.0030 - x0: 0.1094 - y0: -0.0037 - vx0: 0.3784 - vy0: -0.0450 - x: 2.0272 - y: -0.0558 - vx: 0.3693 - vy: -0.0441 - n: 1.1055 - r: 2.0280
# Epoch 39/4000
# 191/200 [===========================>..] - ETA: 0s - loss: 0.5301 - z: 1.0024 - x0: 0.1094 - y0: -0.0037 - vx0: 0.3880 - vy0: -0.0452 - x: 2.0258 - y: -0.0558 - vx: 0.3788 - vy: -0.0442 - n: 1.1076 - r: 2.0266
# Epoch 39: loss improved from 0.53634 to 0.53029, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5303 - z: 1.0029 - x0: 0.1094 - y0: -0.0037 - vx0: 0.3883 - vy0: -0.0452 - x: 2.0271 - y: -0.0558 - vx: 0.3790 - vy: -0.0442 - n: 1.1055 - r: 2.0279
# Epoch 40/4000
# 200/200 [==============================] - ETA: 0s - loss: 0.5244 - z: 1.0000 - x0: 0.1094 - y0: -0.0037 - vx0: 0.3981 - vy0: -0.0451 - x: 2.0216 - y: -0.0557 - vx: 0.3886 - vy: -0.0441 - n: 1.1059 - r: 2.0224
# Epoch 40: loss improved from 0.53029 to 0.52440, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5244 - z: 1.0041 - x0: 0.1094 - y0: -0.0037 - vx0: 0.3982 - vy0: -0.0451 - x: 2.0289 - y: -0.0559 - vx: 0.3886 - vy: -0.0441 - n: 1.1055 - r: 2.0296
# Epoch 41/4000
# 196/200 [============================>.] - ETA: 0s - loss: 0.5195 - z: 0.9955 - x0: 0.1094 - y0: -0.0037 - vx0: 0.4079 - vy0: -0.0451 - x: 2.0129 - y: -0.0554 - vx: 0.3988 - vy: -0.0441 - n: 1.1073 - r: 2.0137
# Epoch 41: loss improved from 0.52440 to 0.51870, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5187 - z: 1.0013 - x0: 0.1094 - y0: -0.0037 - vx0: 0.4080 - vy0: -0.0451 - x: 2.0241 - y: -0.0557 - vx: 0.3989 - vy: -0.0441 - n: 1.1056 - r: 2.0248
# Epoch 42/4000
# 199/200 [============================>.] - ETA: 0s - loss: 0.5129 - z: 0.9996 - x0: 0.1094 - y0: -0.0037 - vx0: 0.4178 - vy0: -0.0452 - x: 2.0205 - y: -0.0557 - vx: 0.4081 - vy: -0.0442 - n: 1.1063 - r: 2.0213
# Epoch 42: loss improved from 0.51870 to 0.51281, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5128 - z: 1.0004 - x0: 0.1094 - y0: -0.0037 - vx0: 0.4178 - vy0: -0.0452 - x: 2.0224 - y: -0.0557 - vx: 0.4082 - vy: -0.0442 - n: 1.1056 - r: 2.0231
# Epoch 43/4000
# 197/200 [============================>.] - ETA: 0s - loss: 0.5096 - z: 0.9904 - x0: 0.1094 - y0: -0.0037 - vx0: 0.4276 - vy0: -0.0449 - x: 2.0041 - y: -0.0552 - vx: 0.4180 - vy: -0.0442 - n: 1.1071 - r: 2.0048
# Epoch 43: loss improved from 0.51281 to 0.50784, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5078 - z: 1.0012 - x0: 0.1094 - y0: -0.0037 - vx0: 0.4277 - vy0: -0.0449 - x: 2.0238 - y: -0.0558 - vx: 0.4180 - vy: -0.0441 - n: 1.1056 - r: 2.0245
# Epoch 44/4000
# 197/200 [============================>.] - ETA: 0s - loss: 0.5023 - z: 0.9944 - x0: 0.1094 - y0: -0.0037 - vx0: 0.4375 - vy0: -0.0453 - x: 2.0106 - y: -0.0554 - vx: 0.4277 - vy: -0.0442 - n: 1.1071 - r: 2.0113
# Epoch 44: loss improved from 0.50784 to 0.50130, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.5013 - z: 1.0035 - x0: 0.1094 - y0: -0.0037 - vx0: 0.4376 - vy0: -0.0453 - x: 2.0275 - y: -0.0559 - vx: 0.4277 - vy: -0.0442 - n: 1.1055 - r: 2.0282
# Epoch 45/4000
# 192/200 [===========================>..] - ETA: 0s - loss: 0.4974 - z: 0.9916 - x0: 0.1094 - y0: -0.0037 - vx0: 0.4473 - vy0: -0.0452 - x: 2.0053 - y: -0.0553 - vx: 0.4375 - vy: -0.0440 - n: 1.1065 - r: 2.0060
# Epoch 45: loss improved from 0.50130 to 0.49596, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.4960 - z: 1.0024 - x0: 0.1094 - y0: -0.0037 - vx0: 0.4475 - vy0: -0.0452 - x: 2.0254 - y: -0.0558 - vx: 0.4377 - vy: -0.0440 - n: 1.1056 - r: 2.0262
# Epoch 46/4000
# 190/200 [===========================>..] - ETA: 0s - loss: 0.4910 - z: 0.9952 - x0: 0.1094 - y0: -0.0037 - vx0: 0.4571 - vy0: -0.0454 - x: 2.0115 - y: -0.0555 - vx: 0.4471 - vy: -0.0442 - n: 1.1084 - r: 2.0123
# Epoch 46: loss improved from 0.49596 to 0.48997, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4900 - z: 1.0017 - x0: 0.1094 - y0: -0.0037 - vx0: 0.4573 - vy0: -0.0454 - x: 2.0240 - y: -0.0558 - vx: 0.4473 - vy: -0.0442 - n: 1.1056 - r: 2.0248
# Epoch 47/4000
# 192/200 [===========================>..] - ETA: 0s - loss: 0.4868 - z: 0.9867 - x0: 0.1094 - y0: -0.0037 - vx0: 0.4670 - vy0: -0.0453 - x: 1.9963 - y: -0.0550 - vx: 0.4570 - vy: -0.0442 - n: 1.1088 - r: 1.9970
# Epoch 47: loss improved from 0.48997 to 0.48435, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4843 - z: 1.0023 - x0: 0.1094 - y0: -0.0037 - vx0: 0.4672 - vy0: -0.0453 - x: 2.0249 - y: -0.0559 - vx: 0.4571 - vy: -0.0442 - n: 1.1056 - r: 2.0257
# Epoch 48/4000
# 191/200 [===========================>..] - ETA: 0s - loss: 0.4781 - z: 1.0061 - x0: 0.1094 - y0: -0.0037 - vx0: 0.4768 - vy0: -0.0453 - x: 2.0308 - y: -0.0561 - vx: 0.4664 - vy: -0.0442 - n: 1.1075 - r: 2.0315
# Epoch 48: loss improved from 0.48435 to 0.47884, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4788 - z: 1.0020 - x0: 0.1094 - y0: -0.0037 - vx0: 0.4770 - vy0: -0.0453 - x: 2.0241 - y: -0.0559 - vx: 0.4667 - vy: -0.0442 - n: 1.1056 - r: 2.0249
# Epoch 49/4000
# 190/200 [===========================>..] - ETA: 0s - loss: 0.4702 - z: 1.0195 - x0: 0.1094 - y0: -0.0037 - vx0: 0.4866 - vy0: -0.0453 - x: 2.0565 - y: -0.0568 - vx: 0.4760 - vy: -0.0442 - n: 1.1039 - r: 2.0573
# Epoch 49: loss improved from 0.47884 to 0.47330, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4733 - z: 0.9972 - x0: 0.1094 - y0: -0.0037 - vx0: 0.4869 - vy0: -0.0453 - x: 2.0149 - y: -0.0556 - vx: 0.4765 - vy: -0.0442 - n: 1.1059 - r: 2.0156
# Epoch 50/4000
# 198/200 [============================>.] - ETA: 0s - loss: 0.4680 - z: 0.9991 - x0: 0.1094 - y0: -0.0037 - vx0: 0.4967 - vy0: -0.0452 - x: 2.0179 - y: -0.0557 - vx: 0.4863 - vy: -0.0442 - n: 1.1066 - r: 2.0187
# Epoch 50: loss improved from 0.47330 to 0.46775, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4678 - z: 1.0028 - x0: 0.1094 - y0: -0.0037 - vx0: 0.4968 - vy0: -0.0452 - x: 2.0249 - y: -0.0559 - vx: 0.4864 - vy: -0.0442 - n: 1.1056 - r: 2.0256
# Epoch 51/4000
# 196/200 [============================>.] - ETA: 0s - loss: 0.4623 - z: 1.0008 - x0: 0.1094 - y0: -0.0037 - vx0: 0.5066 - vy0: -0.0452 - x: 2.0209 - y: -0.0558 - vx: 0.4961 - vy: -0.0442 - n: 1.1064 - r: 2.0216
# Epoch 51: loss improved from 0.46775 to 0.46231, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4623 - z: 1.0011 - x0: 0.1094 - y0: -0.0037 - vx0: 0.5067 - vy0: -0.0452 - x: 2.0215 - y: -0.0559 - vx: 0.4962 - vy: -0.0442 - n: 1.1057 - r: 2.0223
# Epoch 52/4000
# 191/200 [===========================>..] - ETA: 0s - loss: 0.4587 - z: 0.9889 - x0: 0.1094 - y0: -0.0037 - vx0: 0.5163 - vy0: -0.0453 - x: 1.9988 - y: -0.0552 - vx: 0.5057 - vy: -0.0443 - n: 1.1082 - r: 1.9996
# Epoch 52: loss improved from 0.46231 to 0.45675, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4568 - z: 1.0036 - x0: 0.1094 - y0: -0.0037 - vx0: 0.5166 - vy0: -0.0453 - x: 2.0254 - y: -0.0560 - vx: 0.5058 - vy: -0.0443 - n: 1.1057 - r: 2.0262
# Epoch 53/4000
# 197/200 [============================>.] - ETA: 0s - loss: 0.4498 - z: 1.0062 - x0: 0.1094 - y0: -0.0037 - vx0: 0.5263 - vy0: -0.0453 - x: 2.0300 - y: -0.0561 - vx: 0.5153 - vy: -0.0443 - n: 1.0933 - r: 2.0307
# Epoch 53: loss improved from 0.45675 to 0.45158, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4516 - z: 0.9971 - x0: 0.1094 - y0: -0.0037 - vx0: 0.5264 - vy0: -0.0453 - x: 2.0131 - y: -0.0557 - vx: 0.5155 - vy: -0.0443 - n: 1.1060 - r: 2.0138
# Epoch 54/4000
# 196/200 [============================>.] - ETA: 0s - loss: 0.4447 - z: 1.0075 - x0: 0.1094 - y0: -0.0037 - vx0: 0.5362 - vy0: -0.0452 - x: 2.0315 - y: -0.0562 - vx: 0.5252 - vy: -0.0442 - n: 1.1028 - r: 2.0323
# Epoch 54: loss improved from 0.45158 to 0.44611, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4461 - z: 1.0024 - x0: 0.1094 - y0: -0.0037 - vx0: 0.5363 - vy0: -0.0452 - x: 2.0221 - y: -0.0559 - vx: 0.5254 - vy: -0.0442 - n: 1.1057 - r: 2.0229
# Epoch 55/4000
# 190/200 [===========================>..] - ETA: 0s - loss: 0.4378 - z: 1.0139 - x0: 0.1094 - y0: -0.0037 - vx0: 0.5458 - vy0: -0.0453 - x: 2.0424 - y: -0.0566 - vx: 0.5347 - vy: -0.0443 - n: 1.1009 - r: 2.0432
# Epoch 55: loss improved from 0.44611 to 0.44039, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4404 - z: 1.0026 - x0: 0.1094 - y0: -0.0037 - vx0: 0.5461 - vy0: -0.0453 - x: 2.0217 - y: -0.0560 - vx: 0.5352 - vy: -0.0445 - n: 1.1058 - r: 2.0225
# Epoch 56/4000
# 197/200 [============================>.] - ETA: 0s - loss: 0.4349 - z: 1.0010 - x0: 0.1094 - y0: -0.0037 - vx0: 0.5558 - vy0: -0.0451 - x: 2.0180 - y: -0.0559 - vx: 0.5447 - vy: -0.0443 - n: 1.1067 - r: 2.0188
# Epoch 56: loss improved from 0.44039 to 0.43494, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4349 - z: 0.9989 - x0: 0.1094 - y0: -0.0037 - vx0: 0.5559 - vy0: -0.0451 - x: 2.0142 - y: -0.0558 - vx: 0.5448 - vy: -0.0442 - n: 1.1059 - r: 2.0150
# Epoch 57/4000
# 191/200 [===========================>..] - ETA: 0s - loss: 0.4308 - z: 0.9929 - x0: 0.1093 - y0: -0.0037 - vx0: 0.5655 - vy0: -0.0453 - x: 2.0033 - y: -0.0554 - vx: 0.5544 - vy: -0.0440 - n: 1.1073 - r: 2.0041
# Epoch 57: loss improved from 0.43494 to 0.42946, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.4295 - z: 1.0039 - x0: 0.1093 - y0: -0.0037 - vx0: 0.5657 - vy0: -0.0453 - x: 2.0218 - y: -0.0560 - vx: 0.5546 - vy: -0.0440 - n: 1.1059 - r: 2.0226
# Epoch 58/4000
# 196/200 [============================>.] - ETA: 0s - loss: 0.4244 - z: 0.9959 - x0: 0.1093 - y0: -0.0037 - vx0: 0.5755 - vy0: -0.0453 - x: 2.0060 - y: -0.0556 - vx: 0.5642 - vy: -0.0442 - n: 1.1077 - r: 2.0068
# Epoch 58: loss improved from 0.42946 to 0.42364, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.4236 - z: 0.9979 - x0: 0.1093 - y0: -0.0037 - vx0: 0.5756 - vy0: -0.0453 - x: 2.0101 - y: -0.0557 - vx: 0.5643 - vy: -0.0442 - n: 1.1061 - r: 2.0109
# Epoch 59/4000
# 197/200 [============================>.] - ETA: 0s - loss: 0.4194 - z: 0.9921 - x0: 0.1093 - y0: -0.0037 - vx0: 0.5853 - vy0: -0.0453 - x: 1.9980 - y: -0.0554 - vx: 0.5741 - vy: -0.0442 - n: 1.1076 - r: 1.9988
# Epoch 59: loss improved from 0.42364 to 0.41809, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.4181 - z: 1.0026 - x0: 0.1093 - y0: -0.0037 - vx0: 0.5854 - vy0: -0.0453 - x: 2.0174 - y: -0.0559 - vx: 0.5741 - vy: -0.0442 - n: 1.1060 - r: 2.0182
# Epoch 60/4000
# 197/200 [============================>.] - ETA: 0s - loss: 0.4121 - z: 1.0037 - x0: 0.1093 - y0: -0.0037 - vx0: 0.5951 - vy0: -0.0454 - x: 2.0176 - y: -0.0560 - vx: 0.5837 - vy: -0.0443 - n: 1.1072 - r: 2.0184
# Epoch 60: loss improved from 0.41809 to 0.41253, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.4125 - z: 0.9998 - x0: 0.1093 - y0: -0.0037 - vx0: 0.5952 - vy0: -0.0454 - x: 2.0110 - y: -0.0558 - vx: 0.5838 - vy: -0.0443 - n: 1.1061 - r: 2.0118
# Epoch 61/4000
# 187/200 [===========================>..] - ETA: 0s - loss: 0.4079 - z: 0.9929 - x0: 0.1093 - y0: -0.0037 - vx0: 0.6047 - vy0: -0.0452 - x: 1.9973 - y: -0.0554 - vx: 0.5935 - vy: -0.0442 - n: 1.1043 - r: 1.9981
# Epoch 61: loss improved from 0.41253 to 0.40688, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.4069 - z: 1.0023 - x0: 0.1093 - y0: -0.0037 - vx0: 0.6051 - vy0: -0.0452 - x: 2.0138 - y: -0.0559 - vx: 0.5937 - vy: -0.0442 - n: 1.1062 - r: 2.0145
# Epoch 62/4000
# 188/200 [===========================>..] - ETA: 0s - loss: 0.4027 - z: 0.9935 - x0: 0.1093 - y0: -0.0037 - vx0: 0.6146 - vy0: -0.0452 - x: 1.9956 - y: -0.0554 - vx: 0.6034 - vy: -0.0442 - n: 1.1099 - r: 1.9964
# Epoch 62: loss improved from 0.40688 to 0.40127, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.4013 - z: 1.0005 - x0: 0.1093 - y0: -0.0037 - vx0: 0.6149 - vy0: -0.0452 - x: 2.0088 - y: -0.0558 - vx: 0.6036 - vy: -0.0442 - n: 1.1063 - r: 2.0096
# Epoch 63/4000
# 194/200 [============================>.] - ETA: 0s - loss: 0.3960 - z: 0.9991 - x0: 0.1092 - y0: -0.0037 - vx0: 0.6246 - vy0: -0.0452 - x: 2.0041 - y: -0.0557 - vx: 0.6131 - vy: -0.0442 - n: 1.1082 - r: 2.0049
# Epoch 63: loss improved from 0.40127 to 0.39554, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.3955 - z: 0.9982 - x0: 0.1092 - y0: -0.0037 - vx0: 0.6248 - vy0: -0.0452 - x: 2.0025 - y: -0.0556 - vx: 0.6133 - vy: -0.0442 - n: 1.1065 - r: 2.0032
# Epoch 64/4000
# 185/200 [==========================>...] - ETA: 0s - loss: 0.3888 - z: 1.0106 - x0: 0.1092 - y0: -0.0037 - vx0: 0.6342 - vy0: -0.0451 - x: 2.0227 - y: -0.0562 - vx: 0.6226 - vy: -0.0442 - n: 1.1065 - r: 2.0235
# Epoch 64: loss improved from 0.39554 to 0.39058, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3906 - z: 0.9975 - x0: 0.1092 - y0: -0.0037 - vx0: 0.6345 - vy0: -0.0451 - x: 1.9988 - y: -0.0555 - vx: 0.6228 - vy: -0.0441 - n: 1.1067 - r: 1.9996
# Epoch 65/4000
# 197/200 [============================>.] - ETA: 0s - loss: 0.3845 - z: 1.0041 - x0: 0.1092 - y0: -0.0037 - vx0: 0.6442 - vy0: -0.0451 - x: 2.0082 - y: -0.0559 - vx: 0.6325 - vy: -0.0443 - n: 1.1067 - r: 2.0089
# Epoch 65: loss improved from 0.39058 to 0.38503, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3850 - z: 1.0024 - x0: 0.1092 - y0: -0.0037 - vx0: 0.6443 - vy0: -0.0451 - x: 2.0050 - y: -0.0558 - vx: 0.6327 - vy: -0.0443 - n: 1.1067 - r: 2.0058
# Epoch 66/4000
# 199/200 [============================>.] - ETA: 0s - loss: 0.3778 - z: 1.0022 - x0: 0.1091 - y0: -0.0037 - vx0: 0.6540 - vy0: -0.0450 - x: 2.0016 - y: -0.0557 - vx: 0.6423 - vy: -0.0441 - n: 1.1074 - r: 2.0024
# Epoch 66: loss improved from 0.38503 to 0.37807, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.3781 - z: 0.9978 - x0: 0.1091 - y0: -0.0037 - vx0: 0.6541 - vy0: -0.0450 - x: 1.9938 - y: -0.0555 - vx: 0.6423 - vy: -0.0441 - n: 1.1070 - r: 1.9946
# Epoch 67/4000
# 200/200 [==============================] - ETA: 0s - loss: 0.3723 - z: 1.0000 - x0: 0.1091 - y0: -0.0037 - vx0: 0.6638 - vy0: -0.0450 - x: 1.9947 - y: -0.0556 - vx: 0.6519 - vy: -0.0441 - n: 1.1074 - r: 1.9955
# Epoch 67: loss improved from 0.37807 to 0.37227, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.3723 - z: 0.9998 - x0: 0.1091 - y0: -0.0037 - vx0: 0.6638 - vy0: -0.0450 - x: 1.9945 - y: -0.0555 - vx: 0.6519 - vy: -0.0441 - n: 1.1070 - r: 1.9953
# Epoch 68/4000
# 191/200 [===========================>..] - ETA: 0s - loss: 0.3650 - z: 1.0042 - x0: 0.1091 - y0: -0.0037 - vx0: 0.6734 - vy0: -0.0449 - x: 1.9993 - y: -0.0557 - vx: 0.6614 - vy: -0.0441 - n: 1.0958 - r: 2.0001
# Epoch 68: loss improved from 0.37227 to 0.36633, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.3663 - z: 0.9963 - x0: 0.1091 - y0: -0.0037 - vx0: 0.6736 - vy0: -0.0449 - x: 1.9845 - y: -0.0553 - vx: 0.6618 - vy: -0.0441 - n: 1.1078 - r: 1.9852
# Epoch 69/4000
# 191/200 [===========================>..] - ETA: 0s - loss: 0.3570 - z: 1.0180 - x0: 0.1090 - y0: -0.0036 - vx0: 0.6831 - vy0: -0.0449 - x: 2.0203 - y: -0.0564 - vx: 0.6710 - vy: -0.0440 - n: 1.1005 - r: 2.0211
# Epoch 69: loss improved from 0.36633 to 0.36028, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.3603 - z: 1.0026 - x0: 0.1090 - y0: -0.0036 - vx0: 0.6833 - vy0: -0.0449 - x: 1.9925 - y: -0.0556 - vx: 0.6715 - vy: -0.0440 - n: 1.1073 - r: 1.9933
# Epoch 70/4000
# 190/200 [===========================>..] - ETA: 0s - loss: 0.3550 - z: 0.9980 - x0: 0.1090 - y0: -0.0036 - vx0: 0.6929 - vy0: -0.0448 - x: 1.9804 - y: -0.0553 - vx: 0.6807 - vy: -0.0439 - n: 1.1097 - r: 1.9812
# Epoch 70: loss improved from 0.36028 to 0.35437, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3544 - z: 1.0036 - x0: 0.1090 - y0: -0.0036 - vx0: 0.6931 - vy0: -0.0448 - x: 1.9898 - y: -0.0556 - vx: 0.6809 - vy: -0.0439 - n: 1.1075 - r: 1.9906
# Epoch 71/4000
# 199/200 [============================>.] - ETA: 0s - loss: 0.3485 - z: 0.9995 - x0: 0.1089 - y0: -0.0036 - vx0: 0.7028 - vy0: -0.0448 - x: 1.9779 - y: -0.0553 - vx: 0.6906 - vy: -0.0439 - n: 1.1086 - r: 1.9787
# Epoch 71: loss improved from 0.35437 to 0.34835, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.3484 - z: 1.0005 - x0: 0.1089 - y0: -0.0036 - vx0: 0.7029 - vy0: -0.0448 - x: 1.9803 - y: -0.0553 - vx: 0.6907 - vy: -0.0439 - n: 1.1079 - r: 1.9810
# Epoch 72/4000
# 194/200 [============================>.] - ETA: 0s - loss: 0.3390 - z: 1.0138 - x0: 0.1088 - y0: -0.0036 - vx0: 0.7124 - vy0: -0.0447 - x: 1.9996 - y: -0.0559 - vx: 0.6999 - vy: -0.0439 - n: 1.0948 - r: 2.0004
# Epoch 72: loss improved from 0.34835 to 0.34187, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.3419 - z: 0.9985 - x0: 0.1088 - y0: -0.0036 - vx0: 0.7126 - vy0: -0.0447 - x: 1.9720 - y: -0.0551 - vx: 0.7002 - vy: -0.0439 - n: 1.1082 - r: 1.9728
# Epoch 73/4000
# 191/200 [===========================>..] - ETA: 0s - loss: 0.3332 - z: 1.0084 - x0: 0.1088 - y0: -0.0036 - vx0: 0.7221 - vy0: -0.0446 - x: 1.9845 - y: -0.0556 - vx: 0.7095 - vy: -0.0437 - n: 1.0936 - r: 1.9853
# Epoch 73: loss improved from 0.34187 to 0.33563, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.3356 - z: 1.0018 - x0: 0.1088 - y0: -0.0036 - vx0: 0.7223 - vy0: -0.0446 - x: 1.9726 - y: -0.0552 - vx: 0.7099 - vy: -0.0437 - n: 1.1084 - r: 1.9734
# Epoch 74/4000
# 190/200 [===========================>..] - ETA: 0s - loss: 0.3315 - z: 0.9868 - x0: 0.1087 - y0: -0.0036 - vx0: 0.7318 - vy0: -0.0444 - x: 1.9399 - y: -0.0543 - vx: 0.7196 - vy: -0.0437 - n: 1.1128 - r: 1.9406
# Epoch 74: loss improved from 0.33563 to 0.32937, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 5ms/step - loss: 0.3294 - z: 1.0004 - x0: 0.1087 - y0: -0.0036 - vx0: 0.7320 - vy0: -0.0444 - x: 1.9645 - y: -0.0550 - vx: 0.7199 - vy: -0.0437 - n: 1.1087 - r: 1.9653
# Epoch 75/4000
# 191/200 [===========================>..] - ETA: 0s - loss: 0.3217 - z: 1.0085 - x0: 0.1086 - y0: -0.0036 - vx0: 0.7415 - vy0: -0.0445 - x: 1.9725 - y: -0.0553 - vx: 0.7290 - vy: -0.0435 - n: 1.1081 - r: 1.9732
# Epoch 75: loss improved from 0.32937 to 0.32284, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3228 - z: 0.9952 - x0: 0.1086 - y0: -0.0036 - vx0: 0.7418 - vy0: -0.0445 - x: 1.9483 - y: -0.0546 - vx: 0.7294 - vy: -0.0435 - n: 1.1126 - r: 1.9491
# Epoch 76/4000
# 198/200 [============================>.] - ETA: 0s - loss: 0.3159 - z: 1.0000 - x0: 0.1086 - y0: -0.0036 - vx0: 0.7514 - vy0: -0.0443 - x: 1.9513 - y: -0.0547 - vx: 0.7387 - vy: -0.0433 - n: 1.1086 - r: 1.9521
# Epoch 76: loss improved from 0.32284 to 0.31605, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3161 - z: 0.9954 - x0: 0.1086 - y0: -0.0036 - vx0: 0.7515 - vy0: -0.0443 - x: 1.9423 - y: -0.0545 - vx: 0.7389 - vy: -0.0433 - n: 1.1114 - r: 1.9430
# Epoch 77/4000
# 191/200 [===========================>..] - ETA: 0s - loss: 0.3107 - z: 0.9904 - x0: 0.1085 - y0: -0.0036 - vx0: 0.7609 - vy0: -0.0443 - x: 1.9275 - y: -0.0540 - vx: 0.7482 - vy: -0.0433 - n: 1.1111 - r: 1.9283
# Epoch 77: loss improved from 0.31605 to 0.30938, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3094 - z: 1.0042 - x0: 0.1085 - y0: -0.0036 - vx0: 0.7612 - vy0: -0.0443 - x: 1.9505 - y: -0.0548 - vx: 0.7483 - vy: -0.0433 - n: 1.1098 - r: 1.9513
# Epoch 78/4000
# 199/200 [============================>.] - ETA: 0s - loss: 0.3028 - z: 0.9982 - x0: 0.1084 - y0: -0.0036 - vx0: 0.7708 - vy0: -0.0441 - x: 1.9321 - y: -0.0543 - vx: 0.7577 - vy: -0.0432 - n: 1.1111 - r: 1.9328
# Epoch 78: loss improved from 0.30938 to 0.30255, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.3025 - z: 1.0018 - x0: 0.1084 - y0: -0.0036 - vx0: 0.7709 - vy0: -0.0441 - x: 1.9388 - y: -0.0545 - vx: 0.7577 - vy: -0.0432 - n: 1.1103 - r: 1.9395
# Epoch 79/4000
# 193/200 [===========================>..] - ETA: 0s - loss: 0.2967 - z: 0.9920 - x0: 0.1083 - y0: -0.0036 - vx0: 0.7803 - vy0: -0.0440 - x: 1.9143 - y: -0.0538 - vx: 0.7675 - vy: -0.0431 - n: 1.1125 - r: 1.9150
# Epoch 79: loss improved from 0.30255 to 0.29554, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2955 - z: 0.9964 - x0: 0.1083 - y0: -0.0036 - vx0: 0.7805 - vy0: -0.0440 - x: 1.9208 - y: -0.0541 - vx: 0.7676 - vy: -0.0431 - n: 1.1113 - r: 1.9216
# Epoch 80/4000
# 196/200 [============================>.] - ETA: 0s - loss: 0.2880 - z: 1.0018 - x0: 0.1082 - y0: -0.0035 - vx0: 0.7901 - vy0: -0.0438 - x: 1.9222 - y: -0.0541 - vx: 0.7770 - vy: -0.0428 - n: 1.1069 - r: 1.9230
# Epoch 80: loss improved from 0.29554 to 0.28900, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2890 - z: 1.0041 - x0: 0.1082 - y0: -0.0035 - vx0: 0.7902 - vy0: -0.0438 - x: 1.9249 - y: -0.0543 - vx: 0.7771 - vy: -0.0428 - n: 1.1113 - r: 1.9257
# Epoch 81/4000
# 192/200 [===========================>..] - ETA: 0s - loss: 0.2805 - z: 1.0135 - x0: 0.1080 - y0: -0.0035 - vx0: 0.7995 - vy0: -0.0437 - x: 1.9307 - y: -0.0545 - vx: 0.7862 - vy: -0.0428 - n: 1.1104 - r: 1.9315
# Epoch 81: loss improved from 0.28900 to 0.28206, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2821 - z: 0.9981 - x0: 0.1080 - y0: -0.0035 - vx0: 0.7998 - vy0: -0.0437 - x: 1.9041 - y: -0.0537 - vx: 0.7866 - vy: -0.0428 - n: 1.1121 - r: 1.9048
# Epoch 82/4000
# 198/200 [============================>.] - ETA: 0s - loss: 0.2733 - z: 1.0020 - x0: 0.1079 - y0: -0.0035 - vx0: 0.8093 - vy0: -0.0433 - x: 1.8990 - y: -0.0537 - vx: 0.7959 - vy: -0.0429 - n: 1.1136 - r: 1.8997
# Epoch 82: loss improved from 0.28206 to 0.27336, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2734 - z: 0.9998 - x0: 0.1079 - y0: -0.0035 - vx0: 0.8094 - vy0: -0.0433 - x: 1.8956 - y: -0.0536 - vx: 0.7961 - vy: -0.0429 - n: 1.1126 - r: 1.8964
# Epoch 83/4000
# 193/200 [===========================>..] - ETA: 0s - loss: 0.2662 - z: 0.9979 - x0: 0.1078 - y0: -0.0035 - vx0: 0.8189 - vy0: -0.0428 - x: 1.8800 - y: -0.0532 - vx: 0.8058 - vy: -0.0425 - n: 1.1149 - r: 1.8807
# Epoch 83: loss improved from 0.27336 to 0.26578, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# 200/200 [==============================] - 1s 4ms/step - loss: 0.2658 - z: 1.0006 - x0: 0.1078 - y0: -0.0035 - vx0: 0.8190 - vy0: -0.0428 - x: 1.8850 - y: -0.0533 - vx: 0.8059 - vy: -0.0424 - n: 1.1133 - r: 1.8858
# Epoch 84/4000
# 190/200 [===========================>..] - ETA: 0s - loss: 0.2595 - z: 0.9871 - x0: 0.1076 - y0: -0.0035 - vx0: 0.8283 - vy0: -0.0427 - x: 1.8502 - y: -0.0523 - vx: 0.8148 - vy: -0.0422 - n: 1.1147 - r: 1.8509
# Epoch 84: loss improved from 0.26578 to 0.25816, saving model to modelos_agujero_negro\pesos_inter=1_y=0.5_N=200.h5
# ...
# Epoch 3969: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 1.8143e-05 - z: 0.9954 - x0: -0.9998 - y0: 0.4999 - vx0: 0.9280 - vy0: 2.8079e-04 - x: -0.1412 - y: 0.4019 - vx: 0.9760 - vy: -0.2333 - n: 1.1623 - r: 0.6333
# Epoch 3970/4000
# 193/200 [===========================>..] - ETA: 0s - loss: 1.1333e-05 - z: 1.0038 - x0: -1.0001 - y0: 0.5005 - vx0: 0.9284 - vy0: 3.5856e-04 - x: -0.1341 - y: 0.4005 - vx: 0.9751 - vy: -0.2366 - n: 1.1626 - r: 0.6328
# Epoch 3970: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 1.0951e-05 - z: 1.0012 - x0: -1.0001 - y0: 0.5005 - vx0: 0.9284 - vy0: 3.4180e-04 - x: -0.1361 - y: 0.4022 - vx: 0.9765 - vy: -0.2346 - n: 1.1631 - r: 0.6302
# Epoch 3971/4000
# 191/200 [===========================>..] - ETA: 0s - loss: 8.6909e-07 - z: 1.0011 - x0: -1.0000 - y0: 0.5002 - vx0: 0.9285 - vy0: 1.9772e-04 - x: -0.1364 - y: 0.4015 - vx: 0.9765 - vy: -0.2343 - n: 1.1628 - r: 0.6306
# Epoch 3971: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 8.7820e-07 - z: 1.0003 - x0: -1.0000 - y0: 0.5002 - vx0: 0.9285 - vy0: 1.9179e-04 - x: -0.1370 - y: 0.4018 - vx: 0.9769 - vy: -0.2342 - n: 1.1630 - r: 0.6303
# Epoch 3972/4000
# 187/200 [===========================>..] - ETA: 0s - loss: 4.6651e-07 - z: 1.0003 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9284 - vy0: 1.5277e-04 - x: -0.1373 - y: 0.4009 - vx: 0.9758 - vy: -0.2338 - n: 1.1623 - r: 0.6322
# Epoch 3972: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 4.7834e-07 - z: 1.0034 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9284 - vy0: 1.5369e-04 - x: -0.1345 - y: 0.4006 - vx: 0.9761 - vy: -0.2360 - n: 1.1629 - r: 0.6304
# Epoch 3973/4000
# 199/200 [============================>.] - ETA: 0s - loss: 1.8895e-06 - z: 1.0027 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9284 - vy0: 1.7858e-04 - x: -0.1351 - y: 0.4007 - vx: 0.9762 - vy: -0.2357 - n: 1.1631 - r: 0.6301
# Epoch 3973: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 1.8816e-06 - z: 0.9974 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9284 - vy0: 1.6690e-04 - x: -0.1396 - y: 0.4017 - vx: 0.9761 - vy: -0.2336 - n: 1.1626 - r: 0.6315
# Epoch 3974/4000
# 197/200 [============================>.] - ETA: 0s - loss: 2.2938e-06 - z: 0.9937 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9284 - vy0: 8.2262e-05 - x: -0.1429 - y: 0.4024 - vx: 0.9769 - vy: -0.2323 - n: 1.1627 - r: 0.6322
# Epoch 3974: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 2.2879e-06 - z: 1.0035 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9284 - vy0: 9.4785e-05 - x: -0.1345 - y: 0.4003 - vx: 0.9759 - vy: -0.2360 - n: 1.1629 - r: 0.6305
# Epoch 3975/4000
# 198/200 [============================>.] - ETA: 0s - loss: 1.4880e-06 - z: 1.0016 - x0: -1.0000 - y0: 0.5002 - vx0: 0.9284 - vy0: 1.7107e-04 - x: -0.1358 - y: 0.4006 - vx: 0.9758 - vy: -0.2356 - n: 1.1627 - r: 0.6313
# Epoch 3975: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 1.4917e-06 - z: 0.9975 - x0: -0.9999 - y0: 0.5001 - vx0: 0.9284 - vy0: 1.5443e-04 - x: -0.1393 - y: 0.4016 - vx: 0.9762 - vy: -0.2338 - n: 1.1626 - r: 0.6316
# Epoch 3976/4000
# 190/200 [===========================>..] - ETA: 0s - loss: 2.4271e-06 - z: 0.9901 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9285 - vy0: 5.3107e-05 - x: -0.1454 - y: 0.4047 - vx: 0.9788 - vy: -0.2318 - n: 1.1639 - r: 0.6288
# Epoch 3976: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 2.3744e-06 - z: 0.9982 - x0: -1.0000 - y0: 0.5000 - vx0: 0.9284 - vy0: 9.5075e-05 - x: -0.1390 - y: 0.4016 - vx: 0.9761 - vy: -0.2338 - n: 1.1627 - r: 0.6312
# Epoch 3977/4000
# 195/200 [============================>.] - ETA: 0s - loss: 2.4654e-06 - z: 1.0027 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9284 - vy0: 8.9148e-05 - x: -0.1351 - y: 0.4009 - vx: 0.9762 - vy: -0.2360 - n: 1.1632 - r: 0.6302
# Epoch 3977: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 2.4163e-06 - z: 0.9967 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9284 - vy0: 1.1334e-04 - x: -0.1403 - y: 0.4019 - vx: 0.9761 - vy: -0.2334 - n: 1.1625 - r: 0.6321
# Epoch 3978/4000
# 189/200 [===========================>..] - ETA: 0s - loss: 3.2860e-06 - z: 1.0044 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9285 - vy0: 8.0607e-05 - x: -0.1331 - y: 0.4020 - vx: 0.9781 - vy: -0.2359 - n: 1.1642 - r: 0.6254
# Epoch 3978: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 3.4035e-06 - z: 1.0043 - x0: -1.0000 - y0: 0.5002 - vx0: 0.9285 - vy0: 8.1774e-05 - x: -0.1338 - y: 0.4002 - vx: 0.9757 - vy: -0.2364 - n: 1.1628 - r: 0.6306
# Epoch 3979/4000
# 193/200 [===========================>..] - ETA: 0s - loss: 2.6396e-06 - z: 0.9896 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9283 - vy0: 2.1403e-04 - x: -0.1465 - y: 0.4050 - vx: 0.9784 - vy: -0.2306 - n: 1.1635 - r: 0.6295
# Epoch 3979: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 2.6342e-06 - z: 0.9999 - x0: -0.9999 - y0: 0.5001 - vx0: 0.9283 - vy0: 1.9922e-04 - x: -0.1381 - y: 0.4019 - vx: 0.9765 - vy: -0.2341 - n: 1.1630 - r: 0.6302
# Epoch 3980/4000
# 200/200 [==============================] - ETA: 0s - loss: 5.7380e-06 - z: 1.0000 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9284 - vy0: 1.9301e-04 - x: -0.1376 - y: 0.4013 - vx: 0.9764 - vy: -0.2346 - n: 1.1628 - r: 0.6310
# Epoch 3980: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 5.7380e-06 - z: 0.9992 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9284 - vy0: 1.9861e-04 - x: -0.1382 - y: 0.4017 - vx: 0.9767 - vy: -0.2340 - n: 1.1629 - r: 0.6306
# Epoch 3981/4000
# 197/200 [============================>.] - ETA: 0s - loss: 2.4994e-06 - z: 0.9993 - x0: -1.0000 - y0: 0.5002 - vx0: 0.9284 - vy0: 1.3562e-04 - x: -0.1379 - y: 0.4007 - vx: 0.9753 - vy: -0.2346 - n: 1.1621 - r: 0.6332
# Epoch 3981: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 2.4966e-06 - z: 1.0013 - x0: -0.9999 - y0: 0.5002 - vx0: 0.9284 - vy0: 1.3594e-04 - x: -0.1360 - y: 0.4013 - vx: 0.9768 - vy: -0.2348 - n: 1.1631 - r: 0.6300
# Epoch 3982/4000
# 190/200 [===========================>..] - ETA: 0s - loss: 1.2682e-05 - z: 0.9864 - x0: -0.9999 - y0: 0.5001 - vx0: 0.9284 - vy0: 3.8277e-05 - x: -0.1494 - y: 0.4036 - vx: 0.9760 - vy: -0.2294 - n: 1.1613 - r: 0.6367
# Epoch 3982: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 1.2793e-05 - z: 1.0038 - x0: -1.0000 - y0: 0.5002 - vx0: 0.9283 - vy0: 1.6207e-04 - x: -0.1345 - y: 0.4009 - vx: 0.9760 - vy: -0.2352 - n: 1.1627 - r: 0.6312
# Epoch 3983/4000
# 193/200 [===========================>..] - ETA: 0s - loss: 3.1155e-06 - z: 1.0039 - x0: -0.9999 - y0: 0.5002 - vx0: 0.9284 - vy0: 3.2191e-04 - x: -0.1339 - y: 0.4012 - vx: 0.9766 - vy: -0.2341 - n: 1.1630 - r: 0.6291
# Epoch 3983: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 3.0389e-06 - z: 1.0034 - x0: -0.9999 - y0: 0.5002 - vx0: 0.9284 - vy0: 3.0662e-04 - x: -0.1343 - y: 0.4008 - vx: 0.9759 - vy: -0.2354 - n: 1.1628 - r: 0.6306
# Epoch 3984/4000
# 192/200 [===========================>..] - ETA: 0s - loss: 1.3432e-06 - z: 1.0016 - x0: -1.0000 - y0: 0.5002 - vx0: 0.9285 - vy0: 2.3496e-04 - x: -0.1358 - y: 0.4005 - vx: 0.9755 - vy: -0.2357 - n: 1.1623 - r: 0.6329
# Epoch 3984: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 1.4308e-06 - z: 0.9972 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9285 - vy0: 2.3469e-04 - x: -0.1395 - y: 0.4020 - vx: 0.9764 - vy: -0.2333 - n: 1.1625 - r: 0.6319
# Epoch 3985/4000
# 195/200 [============================>.] - ETA: 0s - loss: 1.7550e-06 - z: 0.9932 - x0: -1.0001 - y0: 0.5002 - vx0: 0.9284 - vy0: 2.1819e-04 - x: -0.1432 - y: 0.4025 - vx: 0.9763 - vy: -0.2321 - n: 1.1623 - r: 0.6336
# Epoch 3985: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 1.7460e-06 - z: 1.0025 - x0: -1.0000 - y0: 0.5002 - vx0: 0.9284 - vy0: 2.0938e-04 - x: -0.1351 - y: 0.4011 - vx: 0.9763 - vy: -0.2356 - n: 1.1630 - r: 0.6302
# Epoch 3986/4000
# 200/200 [==============================] - ETA: 0s - loss: 2.5654e-05 - z: 1.0000 - x0: -0.9998 - y0: 0.5000 - vx0: 0.9283 - vy0: 2.7443e-04 - x: -0.1376 - y: 0.4012 - vx: 0.9761 - vy: -0.2340 - n: 1.1628 - r: 0.6308
# Epoch 3986: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 2.5654e-05 - z: 0.9980 - x0: -0.9998 - y0: 0.5000 - vx0: 0.9283 - vy0: 2.6806e-04 - x: -0.1393 - y: 0.4017 - vx: 0.9762 - vy: -0.2331 - n: 1.1627 - r: 0.6311
# Epoch 3987/4000
# 200/200 [==============================] - ETA: 0s - loss: 1.5139e-06 - z: 1.0000 - x0: -1.0000 - y0: 0.5004 - vx0: 0.9284 - vy0: 4.0951e-04 - x: -0.1372 - y: 0.4023 - vx: 0.9761 - vy: -0.2334 - n: 1.1625 - r: 0.6317
# Epoch 3987: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 1.5139e-06 - z: 0.9960 - x0: -1.0000 - y0: 0.5004 - vx0: 0.9284 - vy0: 4.0969e-04 - x: -0.1406 - y: 0.4028 - vx: 0.9760 - vy: -0.2323 - n: 1.1621 - r: 0.6333
# Epoch 3988/4000
# 190/200 [===========================>..] - ETA: 0s - loss: 6.4050e-07 - z: 0.9938 - x0: -1.0000 - y0: 0.5003 - vx0: 0.9285 - vy0: 3.1004e-04 - x: -0.1425 - y: 0.4033 - vx: 0.9771 - vy: -0.2310 - n: 1.1624 - r: 0.6321
# Epoch 3988: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 6.2457e-07 - z: 1.0022 - x0: -1.0000 - y0: 0.5003 - vx0: 0.9284 - vy0: 3.2695e-04 - x: -0.1352 - y: 0.4016 - vx: 0.9766 - vy: -0.2349 - n: 1.1629 - r: 0.6304
# Epoch 3989/4000
# 192/200 [===========================>..] - ETA: 0s - loss: 6.2720e-07 - z: 1.0112 - x0: -1.0000 - y0: 0.5002 - vx0: 0.9285 - vy0: 2.2625e-04 - x: -0.1276 - y: 0.3998 - vx: 0.9762 - vy: -0.2370 - n: 1.1632 - r: 0.6278
# Epoch 3989: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 6.0917e-07 - z: 1.0029 - x0: -1.0000 - y0: 0.5002 - vx0: 0.9285 - vy0: 2.3118e-04 - x: -0.1346 - y: 0.4011 - vx: 0.9763 - vy: -0.2354 - n: 1.1629 - r: 0.6304
# Epoch 3990/4000
# 196/200 [============================>.] - ETA: 0s - loss: 9.2489e-07 - z: 0.9975 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9285 - vy0: 1.7665e-04 - x: -0.1390 - y: 0.4030 - vx: 0.9779 - vy: -0.2335 - n: 1.1636 - r: 0.6285
# Epoch 3990: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 9.8208e-07 - z: 0.9964 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9285 - vy0: 1.7632e-04 - x: -0.1403 - y: 0.4019 - vx: 0.9761 - vy: -0.2334 - n: 1.1625 - r: 0.6324
# Epoch 3991/4000
# 190/200 [===========================>..] - ETA: 0s - loss: 2.1980e-06 - z: 1.0154 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9283 - vy0: 1.5077e-04 - x: -0.1243 - y: 0.3996 - vx: 0.9768 - vy: -0.2392 - n: 1.1644 - r: 0.6243
# Epoch 3991: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 2.1625e-06 - z: 0.9978 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9283 - vy0: 1.5135e-04 - x: -0.1395 - y: 0.4018 - vx: 0.9762 - vy: -0.2335 - n: 1.1626 - r: 0.6314
# Epoch 3992/4000
# 194/200 [============================>.] - ETA: 0s - loss: 3.6002e-06 - z: 1.0073 - x0: -0.9999 - y0: 0.5001 - vx0: 0.9284 - vy0: 8.9644e-05 - x: -0.1310 - y: 0.3998 - vx: 0.9763 - vy: -0.2378 - n: 1.1634 - r: 0.6294
# Epoch 3992: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 3.5555e-06 - z: 0.9997 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9285 - vy0: 1.2595e-04 - x: -0.1374 - y: 0.4016 - vx: 0.9768 - vy: -0.2342 - n: 1.1630 - r: 0.6302
# Epoch 3993/4000
# 196/200 [============================>.] - ETA: 0s - loss: 1.4890e-06 - z: 1.0041 - x0: -1.0000 - y0: 0.5002 - vx0: 0.9284 - vy0: 1.7044e-04 - x: -0.1338 - y: 0.4008 - vx: 0.9763 - vy: -0.2356 - n: 1.1630 - r: 0.6297
# Epoch 3993: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 1.4785e-06 - z: 1.0030 - x0: -1.0000 - y0: 0.5002 - vx0: 0.9284 - vy0: 1.6898e-04 - x: -0.1347 - y: 0.4008 - vx: 0.9761 - vy: -0.2359 - n: 1.1630 - r: 0.6303
# Epoch 3994/4000
# 199/200 [============================>.] - ETA: 0s - loss: 1.2064e-06 - z: 0.9993 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9284 - vy0: 1.1468e-04 - x: -0.1380 - y: 0.4011 - vx: 0.9760 - vy: -0.2346 - n: 1.1625 - r: 0.6320
# Epoch 3994: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 1.2108e-06 - z: 1.0007 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9284 - vy0: 1.1988e-04 - x: -0.1367 - y: 0.4015 - vx: 0.9769 - vy: -0.2346 - n: 1.1631 - r: 0.6301
# Epoch 3995/4000
# 194/200 [============================>.] - ETA: 0s - loss: 6.1428e-06 - z: 0.9952 - x0: -0.9999 - y0: 0.5002 - vx0: 0.9283 - vy0: 2.4346e-04 - x: -0.1413 - y: 0.4015 - vx: 0.9752 - vy: -0.2333 - n: 1.1618 - r: 0.6349
# Epoch 3995: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 6.1461e-06 - z: 1.0019 - x0: -0.9999 - y0: 0.5001 - vx0: 0.9284 - vy0: 2.2883e-04 - x: -0.1352 - y: 0.4013 - vx: 0.9764 - vy: -0.2354 - n: 1.1631 - r: 0.6300
# Epoch 3996/4000
# 195/200 [============================>.] - ETA: 0s - loss: 1.6105e-06 - z: 0.9963 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9284 - vy0: 1.1549e-04 - x: -0.1403 - y: 0.4017 - vx: 0.9761 - vy: -0.2335 - n: 1.1624 - r: 0.6327
# Epoch 3996: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 1.7610e-06 - z: 0.9989 - x0: -1.0001 - y0: 0.5001 - vx0: 0.9284 - vy0: 1.2793e-04 - x: -0.1380 - y: 0.4016 - vx: 0.9765 - vy: -0.2338 - n: 1.1628 - r: 0.6307
# Epoch 3997/4000
# 194/200 [============================>.] - ETA: 0s - loss: 3.0952e-06 - z: 1.0044 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9284 - vy0: 1.0558e-04 - x: -0.1334 - y: 0.4022 - vx: 0.9778 - vy: -0.2347 - n: 1.1639 - r: 0.6255
# Epoch 3997: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 3.0368e-06 - z: 0.9953 - x0: -0.9999 - y0: 0.5001 - vx0: 0.9284 - vy0: 8.4505e-05 - x: -0.1414 - y: 0.4018 - vx: 0.9760 - vy: -0.2333 - n: 1.1624 - r: 0.6332
# Epoch 3998/4000
# 196/200 [============================>.] - ETA: 0s - loss: 2.0624e-06 - z: 1.0082 - x0: -1.0000 - y0: 0.5001 - vx0: 0.9284 - vy0: 2.2256e-04 - x: -0.1300 - y: 0.3999 - vx: 0.9760 - vy: -0.2369 - n: 1.1632 - r: 0.6281
# Epoch 3998: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 2.1170e-06 - z: 0.9954 - x0: -1.0000 - y0: 0.5002 - vx0: 0.9284 - vy0: 2.1503e-04 - x: -0.1409 - y: 0.4016 - vx: 0.9760 - vy: -0.2336 - n: 1.1624 - r: 0.6330
# Epoch 3999/4000
# 197/200 [============================>.] - ETA: 0s - loss: 3.8438e-06 - z: 1.0009 - x0: -0.9997 - y0: 0.5001 - vx0: 0.9284 - vy0: 7.0078e-05 - x: -0.1366 - y: 0.4012 - vx: 0.9761 - vy: -0.2345 - n: 1.1629 - r: 0.6299
# Epoch 3999: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 4.2816e-06 - z: 1.0007 - x0: -0.9999 - y0: 0.5000 - vx0: 0.9283 - vy0: 1.1308e-04 - x: -0.1366 - y: 0.4014 - vx: 0.9765 - vy: -0.2348 - n: 1.1632 - r: 0.6297
# Epoch 4000/4000
# 198/200 [============================>.] - ETA: 0s - loss: 4.8429e-06 - z: 0.9961 - x0: -0.9999 - y0: 0.5000 - vx0: 0.9285 - vy0: 7.5725e-05 - x: -0.1401 - y: 0.4020 - vx: 0.9771 - vy: -0.2328 - n: 1.1623 - r: 0.6327
# Epoch 4000: loss did not improve from 0.00000
# 200/200 [==============================] - 1s 5ms/step - loss: 4.8009e-06 - z: 1.0001 - x0: -0.9999 - y0: 0.5000 - vx0: 0.9285 - vy0: 8.4482e-05 - x: -0.1366 - y: 0.4017 - vx: 0.9775 - vy: -0.2337 - n: 1.1628 - r: 0.6306
# 7/7 [==============================] - 0s 2ms/step

# %% [markdown]
# # Plot loss vs (last) epochs

# %%
#* summarize history for loss
plt.plot(np.log10(history.history['loss']),marker='o',markersize=0.0, linewidth=1)
plt.xlabel('época',fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.legend(['función coste'], loc='upper left')
plt.show()

# %%
z_red=z_train
model.load_weights(f'black_hole_models/weights_inter={N_intervalos}_y={y_ini}_N={N_train_max}.h5')
#? Use if you are going to plot some save model
#z_red=np.linspace(zmin,zmax,40)
#z_red=np.reshape(z_red,(200,1))
xy_pred=model.predict(z_red)
# Out:
# 7/7 [==============================] - 0s 2ms/step

# %% [markdown]
# ## RK definitions

# %%
def f_x(t, x, y, vx, vy):
    #* vx's ODE
    return vx/n_xy(x,y)

def f_y(t, x, y, vx, vy):
    #* vy's ODE
    return vy/n_xy(x, y)

def g_x(t, x, y, vx, vy):
    #* ax's ODE
    return -n_xy(x,y)**2*2*GM_c2*x/((x**2+y**2+epsilon2**2)**(3/2))

def g_y(t, x, y, vx, vy):
    #* ay's ODE
    return -n_xy(x,y)**2*2*GM_c2*y/((x**2+y**2+epsilon2**2)**(3/2))

def n_xy(x, y):
    #*Ecuación que calcula el índice de refracción
    return (1/(1-(2*GM_c2/(x**2+y**2+epsilon2**2)**0.5)))

#* fourth order runge kutta
def runge_kutta_4th_order(t, x, y, vx, vy, h):

    k1_x = h * f_x(t, x, y, vx, vy)
    k1_y = h * f_y(t, x, y, vx, vy)
    k1_vx = h * g_x(t, x, y, vx, vy)
    k1_vy = h * g_y(t, x, y, vx, vy)

    k2_x = h * f_x(t + 0.5 * h, x + 0.5 * k1_x, y + 0.5 * k1_y, vx + 0.5 * k1_vx, vy + 0.5 * k1_vy)
    k2_y = h * f_y(t + 0.5 * h, x + 0.5 * k1_x, y + 0.5 * k1_y, vx + 0.5 * k1_vx, vy + 0.5 * k1_vy)
    k2_vx = h * g_x(t + 0.5 * h, x + 0.5 * k1_x, y + 0.5 * k1_y, vx + 0.5 * k1_vx, vy + 0.5 * k1_vy)
    k2_vy = h * g_y(t + 0.5 * h, x + 0.5 * k1_x, y + 0.5 * k1_y, vx + 0.5 * k1_vx, vy + 0.5 * k1_vy)

    k3_x = h * f_x(t + 0.5 * h, x + 0.5 * k2_x, y + 0.5 * k2_y, vx + 0.5 * k2_vx, vy + 0.5 * k2_vy)
    k3_y = h * f_y(t + 0.5 * h, x + 0.5 * k2_x, y + 0.5 * k2_y, vx + 0.5 * k2_vx, vy + 0.5 * k2_vy)
    k3_vx = h * g_x(t + 0.5 * h, x + 0.5 * k2_x, y + 0.5 * k2_y, vx + 0.5 * k2_vx, vy + 0.5 * k2_vy)
    k3_vy = h * g_y(t + 0.5 * h, x + 0.5 * k2_x, y + 0.5 * k2_y, vx + 0.5 * k2_vx, vy + 0.5 * k2_vy)

    k4_x = h * f_x(t + h, x + k3_x, y + k3_y, vx + k3_vx, vy + k3_vy)
    k4_y = h * f_y(t + h, x + k3_x, y + k3_y, vx + k3_vx, vy + k3_vy)
    k4_vx = h * g_x(t + h, x + k3_x, y + k3_y, vx + k3_vx, vy + k3_vy)
    k4_vy = h * g_y(t + h, x + k3_x, y + k3_y, vx + k3_vx, vy + k3_vy)

    new_x = x + (1/6) * (k1_x + 2 * k2_x + 2 * k3_x + k4_x)
    new_y = y + (1/6) * (k1_y + 2 * k2_y + 2 * k3_y + k4_y)
    new_vx = vx + (1/6) * (k1_vx + 2 * k2_vx + 2 * k3_vx + k4_vx)
    new_vy = vy + (1/6) * (k1_vy + 2 * k2_vy + 2 * k3_vy + k4_vy)

    return new_x, new_y, new_vx, new_vy

# %% [markdown]
# ## Run RK

# %%
#* RK's initial conditions

t0 = 0.0
tfin=2
h = 0.01  # time step
pasos= int((tfin-t0)/h)
epsilon=0.1
epsilon2=0

x_tot=[]
y_tot=[]
vx_tot=[]
vy_tot=[]
t_tot=[]

x_tot.append(x0_rk)
y_tot.append(y0_rk)
vx_tot.append(vx0_rk)
vy_tot.append(vy0_rk)
t_tot.append(t0)


x_rk=x0_rk; y_rk=y0_rk; vx_rk=vx0_rk; vy_rk=vy0_rk
for i in range(pasos):
    x_rk, y_rk, vx_rk, vy_rk = runge_kutta_4th_order(t0, x_rk, y_rk, vx_rk, vy_rk, h)
    if (((x_rk**2+y_rk**2)**0.5)<A+0.001):

        break
    x_tot.append(x_rk)
    y_tot.append(y_rk)
    vx_tot.append(vx_rk)
    vy_tot.append(vy_rk)
    t0 += h
    t_tot.append(t0)

# %% [markdown]
# # Plot the results

# %%
chinchetas=np.array(auxx)

fig, ax = plt.subplots(dpi=100)
#* RK
ax.plot(t_tot, vx_tot, linestyle='-', linewidth=0.5,color='b', label='px(s) RK')
ax.plot(t_tot, vy_tot, linestyle='-', linewidth=0.5,color='g', label='py(s) RK')

#* PINN
ax.plot(z_red, xy_pred[:,2], color="red",marker='o',markersize=2.0, linestyle='solid', linewidth=0.5, label="px(s) PINN")
ax.plot(z_red, xy_pred[:,3], color="orange",marker='o',markersize=2.0, linestyle='solid', linewidth=0.5, label="py(s) PINN")

#*"Chinchetas"
ax.plot(aux2, chinchetas[:,2], "o", markersize=6, color='blue', label='chinchetas px')
ax.plot(aux2, chinchetas[:,3], "o", markersize=6, color='green', label='chinchetas py')

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

ax.set_xlabel('s (parametrization)', fontsize=16)
ax.set_ylabel('(px,py) coordinates', fontsize=16)

#* Adds a legend
ax.legend()

#* Show grafic
#plt.gca().set_aspect('equal', adjustable='box')

plt.grid(True)  # Optional
#plt.xlim(0,60)
#plt.ylim(0,1.1)
plt.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                mode="expand", borderaxespad=0, ncol=2,fontsize=12)

fig.set_size_inches(6,6)
#?Save the plot
#fig.savefig(f'Black_hole_velocity_chinchetas={N_intervalos}_y={y_ini}_N={N_train_max}_.png',bbox_inches='tight', dpi=600)

plt.show()

# %%
fig, ax = plt.subplots(dpi=150)
#* RK
ax.plot(x_tot, y_tot, linestyle='-', linewidth=0.5,color='b', label='RK')

#* Chinchetas
ax.plot(chinchetas[:,0], chinchetas[:,1], "o", markersize=5, color='blue', label='RK')

#* PINN
ax.plot(xy_pred[:,0], xy_pred[:,1], color="red",marker='o',markersize=2.0, linestyle='solid', linewidth=0.5, label="PINN")

plt.xticks(fontsize=14)
plt.yticks(fontsize=14)

#* Adds the horizont event circle
circle = Circle((0, 0), A, fill=False, color='black', linestyle='-')
#circle = Circle((0, 0), A*3*10**8, fill=False, color='black', linestyle='-')
ax.add_patch(circle)

ax.set_xlabel('X (3·$10^8$ m)')
ax.set_ylabel('Y (3·$10^8$ m)')

#* Add legend
ax.legend()

#* Show grafic
plt.gca().set_aspect('equal', adjustable='box')

plt.grid(True)  # Optional
#plt.xlim(-100,-88)
#plt.ylim(48,51)

plt.legend(loc='upper right', bbox_to_anchor=(1.0, 1.2))

plt.legend(bbox_to_anchor=(0,1.02,1,0.2), loc="lower left",
                mode="expand", borderaxespad=0, ncol=2,fontsize=12)

fig.set_size_inches(6,6)
#? Save the plot
#plt.savefig(f'Black_hole_trajectorie_chinchetas={N_intervalos}_y={y_ini}_N={N_train_max}_.png',bbox_inches='tight', dpi=600)
plt.show()

# %% [markdown]
# # Error cometido

# %%
error=0

diff_inter=int(pasos/N_train_max)

for i in range (N_train_max):
    error=error+(x_tot[i*diff_inter]-xy_pred[i,0])**2
    error=error+(y_tot[i*diff_inter]-xy_pred[i,1])**2
    error=error+(vx_tot[i*diff_inter]-xy_pred[i,2])**2
    error=error+(vy_tot[i*diff_inter]-xy_pred[i,3])**2

print(f"n pusphin={N_intervalos-1} error={error}")
# Out:
# n chinchetas=0 error=0.006569848287948759

# %%
#* We save the PINN data trajectories
ruta_error = f'multiple_black_hole/pushpin_error_y{y_ini}.txt'

with open(ruta_error, 'a') as archivo:
    archivo.write(f'{N_intervalos-1}\t{error}\n')

# %% [markdown]
# # Guardar chinchetas

# %%
chincheta_aux=[]
for i in aux2:
    chincheta_aux.append(i[0])
print(chincheta_aux)
# Out:
# [1.0, 2.0]

# %%
#* We save the PINN data trajectories
ruta_chinchetas = f'multiple_black_hole/pushpin_y0={y_ini}_Ninter={N_intervalos}.txt'

with open(ruta_chinchetas, 'w') as archivo:
    for valor1, valor2, valor3, valor4, valor5 in zip(chincheta_aux, chinchetas[:,0], chinchetas[:,1], chinchetas[:,2], chinchetas[:,3]):
        archivo.write(f'{valor1}\t{valor2}\t{valor3}\t{valor4}\t{valor5}\n')
